# %% [markdown]
# # Notebook Image Test
#
# Testing whether relative image paths render on GitHub.
#
# ## Test 1: Markdown syntax, relative path
#
# ![test image](images/test.png)
#
# ## Test 2: Markdown syntax, relative path with ./
#
# ![test image](./images/test.png)
#
# ## Test 3: HTML img tag, relative path
#
# <img src="images/test.png" alt="test image" width="400"/>
#
# ## Test 4: HTML img tag, relative path with ./
#
# <img src="./images/test.png" alt="test image" width="400"/>
#
# If any of the above show a green rectangle, relative paths work.
