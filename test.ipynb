# %% [markdown]
# # Notebook Image Test: LFS vs Non-LFS
#
# ## Test 1: Regular git object (green, should work)
#
# ![green non-lfs](images/test.png)
#
# ## Test 2: Git LFS tracked (blue, may be broken)
#
# ![blue lfs](images/lfs-test.png)
#
# ---
#
# If you see a green box but NOT a blue box, Git LFS is the problem.
